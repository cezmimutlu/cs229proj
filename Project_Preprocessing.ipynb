# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans

# %%
# Upload the data and clean up.
data = pd.read_csv("h1b_data.csv")
data = data.dropna(axis=0, how='any')
data = data[~data.CASE_STATUS.str.contains('WITHDRAWN')]
data = data.replace(to_replace="CERTIFIED", value=1)
data = data.replace(to_replace="DENIED", value=0)
data = data.replace(to_replace="CERTIFIED", value=1)
data = data.replace(to_replace="DENIED", value=0)
data = data.drop('lon', 1)
data = data.drop('lat', 1)
data = data.drop('Unnamed: 0', 1)

data['FULL_TIME_POSITION'].replace(['Y','N'],['1','0'],inplace=True)
Cities,States = data['WORKSITE'].str.split(', ',1).str
city_to_state = dict(zip(data['WORKSITE'], States))
data['WORKSITE']= data['WORKSITE'].map(city_to_state)
data
# Out:
#         CASE_STATUS                                    EMPLOYER_NAME  \
# 18                1                                   QUICKLOGIX LLC
# 19                1                            MCCHRYSTAL GROUP, LLC
# 22                1                                      LOMICS, LLC
# 23                1         UC UNIVERSITY HIGH SCHOOL EDUCATION INC.
# 25                1                                 QUICKLOGIX, INC.
# 27                1                                       HELLO INC.
# 28                1                                       UMBEL CORP
# 29                1          PERSPECTIVES OF FREEDOM FOUNDATION, INC
# 30                1                                         GTH INC.
# 31                1                          THE KRAFT HEINZ COMPANY
# 32                1                                      REGED, INC.
# 33                1                           VMS COMMUNICATIONS LLC
# 34                1          FINLAY EXTRACTS & INGREDIENTS USA, INC.
# 36                1                                    LABEL INSIGHT
# 37                1                         INN AT THE WICKLIFFE LLC
# 38                1                       DURHAM SCHOOL SERVICES, LP
# 39                0                                  PARALLELS, INC.
# 40                1                               CB LANSING 300 LLP
# 41                1                SOFTTEK INTEGRATION SYSTEMS, INC.
# 42                1                                    SPARITY, INC.
# 43                1                            ADCONION DIRECT, INC.
# 44                1                                MAVENCARE US INC.
# 46                1                                MED ADVANTAGE LLC
# 47                0                             RANCHO LA PUERTA LLC
# 48                1                                 STRATEGISM, INC.
# 49                1                             RANCHO LA PUERTA LLC
# 50                1            SPRING BRANCH COMMUNITY HEALTH CENTER
# 51                1            SPRING BRANCH COMMUNITY HEALTH CENTER
# 52                1                         PAXTERRA SOLUTIONS, INC.
# 53                1                                  PARALLELS, INC.
# ...             ...                                              ...
# 3002316           0                            MEDNET ASSOCIATES INC
# 3002318           0                              THE CERVANTES GROUP
# 3002319           0          BENCHMARK FURNITURE MANUFACTURING, INC.
# 3002320           0                                  IBM CORPORATION
# 3002323           0                                   CLERYSYS, INC.
# 3002326           0                                     TECHWOOD INC
# 3002327           0                         SUNERA TECHNOLOGIES, INC
# 3002328           0      NORTH FLORIDA REGIONAL MEDICAL CENTER, INC.
# 3002330           0                                         BATTELLE
# 3002331           0                  LANGER RESEARCH ASSOCIATES, LLC
# 3002333           0                  OLYMPIC COMPUTER SERVICES, INC.
# 3002336           0                         SUNERA TECHNOLOGIES, INC
# 3002339           0                           HEALTHBRIDGE USA, INC.
# 3002346           0                                   MINDTECK, INC.
# 3002347           0                                   SYNOPSYS, INC.
# 3002348           0               JUNG & LEE ACCOUNTANCY CORPORATION
# 3002350           0                          GRAYWEBGRAPHICS.COM LLC
# 3002353           0  CENTERS FOR DISEASE CONTROL AND PREVENTION/DHHS
# 3002354           0                                       IIDYA CORP
# 3002356           0                                       IIDYA CORP
# 3002357           0                         TEJASE TECHNOLOGIES INC.
# 3002360           0                         ERICSSON TELEVISION INC.
# 3002364           0             UNIVERSITY OF CALIFORNIA, SANTA CRUZ
# 3002366           0                                 PARKS ASSOCIATES
# 3002367           0               OREGON HEALTH & SCIENCE UNIVERSITY
# 3002369           0                                   CUSTOMTBT, LLC
# 3002378           0                     KEVIN PARK & ASSOCIATES, LTD
# 3002383           0                             IVERTIX INCORPORATED
# 3002389           0                        PROGRESSIVE SURFACE, INC.
# 3002392           0                   PEI PARTNERSHIP ARCHITECTS LLP
#
#                                                   SOC_NAME  \
# 18                                        CHIEF EXECUTIVES
# 19                                        CHIEF EXECUTIVES
# 22                                        CHIEF EXECUTIVES
# 23                                        CHIEF EXECUTIVES
# 25                                        CHIEF EXECUTIVES
# 27                                        CHIEF EXECUTIVES
# 28                                        CHIEF EXECUTIVES
# 29                                        CHIEF EXECUTIVES
# 30                                        CHIEF EXECUTIVES
# 31                                        CHIEF EXECUTIVES
# 32                                        CHIEF EXECUTIVES
# 33                                        CHIEF EXECUTIVES
# 34                                        CHIEF EXECUTIVES
# 36                                        CHIEF EXECUTIVES
# 37                                        CHIEF EXECUTIVES
# 38                                        CHIEF EXECUTIVES
# 39                                        CHIEF EXECUTIVES
# 40                                        CHIEF EXECUTIVES
# 41                                        CHIEF EXECUTIVES
# 42                                        CHIEF EXECUTIVES
# 43                                        CHIEF EXECUTIVES
# 44                                        CHIEF EXECUTIVES
# 46                                        CHIEF EXECUTIVES
# 47                                        CHIEF EXECUTIVES
# 48                                        CHIEF EXECUTIVES
# 49                                        CHIEF EXECUTIVES
# 50                                        CHIEF EXECUTIVES
# 51                                        CHIEF EXECUTIVES
# 52                                        CHIEF EXECUTIVES
# 53                                        CHIEF EXECUTIVES
# ...                                                    ...
# 3002316                   Computer Occupations, All Other*
# 3002318  Human Resources, Training, and Labor Relations...
# 3002319                                Management Analysts
# 3002320                                Management Analysts
# 3002323                               Computer Programmers
# 3002326                                    Cost Estimators
# 3002327                          Computer Systems Analysts
# 3002328                                        Pharmacists
# 3002330                                           Chemists
# 3002331  Market Research Analysts and Marketing Special...
# 3002333       Network and Computer Systems Administrators*
# 3002336                          Computer Systems Analysts
# 3002339                                   Chief Executives
# 3002346                               Computer Programmers
# 3002347       Network and Computer Systems Administrators*
# 3002348                           Accountants and Auditors
# 3002350                                  Graphic Designers
# 3002353                                   Health Educators
# 3002354                               Computer Programmers
# 3002356                               Computer Programmers
# 3002357                            Database Administrators
# 3002360              Software Developers, Systems Software
# 3002364                      Biochemists and Biophysicists
# 3002366  Market Research Analysts and Marketing Special...
# 3002367         Medical Scientists, Except Epidemiologists
# 3002369                         Instructional Coordinators
# 3002378                           Accountants and Auditors
# 3002383                               Computer Programmers
# 3002389                                    Sales Engineers
# 3002392                   Architectural and Civil Drafters
# 3002383                            APPLICATION DEVELOPER                  1
# 3002389                                   SALES ENGINEER                  1
# 3002392                           ARCHITECTURAL DESIGNER                  1
#
#          PREVAILING_WAGE    YEAR              WORKSITE
# 18             187200.00  2016.0            CALIFORNIA
# 19             241842.00  2016.0              VIRGINIA
# 22              99986.00  2016.0            CALIFORNIA
# 23              99986.00  2016.0            CALIFORNIA
# 25             187200.00  2016.0            CALIFORNIA
# 27             215862.00  2016.0            CALIFORNIA
# 28             192088.00  2016.0                 TEXAS
# 29              95295.98  2016.0               FLORIDA
# 30             149594.00  2016.0  DISTRICT OF COLUMBIA
# 31             226699.00  2016.0              ILLINOIS
# 32             187200.00  2016.0        NORTH CAROLINA
# 33             159370.00  2016.0               FLORIDA
# 34              98550.00  2016.0          RHODE ISLAND
# 36             130853.00  2016.0              ILLINOIS
# 37              52416.00  2016.0                  OHIO
# 38             130853.00  2016.0              ILLINOIS
# 39             187200.00  2016.0            WASHINGTON
# 40              89107.00  2016.0              MICHIGAN
# 41             130853.00  2016.0              ILLINOIS
# 42             102190.00  2016.0               GEORGIA
# 43             197683.00  2016.0            CALIFORNIA
# 44             122179.00  2016.0              NEW YORK
# 46             187200.00  2016.0            NEW JERSEY
# 47             197683.20  2016.0            CALIFORNIA
# 48             155459.20  2016.0            CALIFORNIA
# 49             197683.20  2016.0            CALIFORNIA
# 50             187200.00  2016.0                 TEXAS
# 51             187200.00  2016.0                 TEXAS
# 52             102190.00  2016.0               GEORGIA
# 53             187200.00  2016.0            WASHINGTON
# ...                  ...     ...                   ...
# 3002316         46946.00  2011.0         MASSACHUSETTS
# 3002318         29910.00  2011.0           PUERTO RICO
# 3002319         58531.00  2011.0              NEW YORK
# 3002320         68349.00  2011.0                NEVADA
# 3002323         52478.00  2011.0            NEW JERSEY
# 3002326         48090.00  2011.0              NEW YORK
# 3002327         73507.00  2011.0        NORTH CAROLINA
# 3002328         91749.00  2011.0               FLORIDA
# 3002330         47653.00  2011.0            WASHINGTON
# 3002331         73174.00  2011.0              NEW YORK
# 3002333         54121.60  2011.0            NEW JERSEY
# 3002336         63107.00  2011.0            CALIFORNIA
# 3002339        226325.00  2011.0               GEORGIA
# 3002346         64792.00  2011.0        NORTH CAROLINA
# 3002347         94198.00  2011.0            CALIFORNIA
# 3002348         59737.60  2011.0            CALIFORNIA
# 3002350         24856.00  2011.0                 TEXAS
# 3002353         33134.00  2011.0                  OHIO
# 3002354         43368.00  2011.0                OREGON
# 3002356         46488.00  2011.0                 TEXAS
# 3002357         56493.00  2011.0                  IOWA
# 3002360         79206.00  2011.0               GEORGIA
# 3002364         38496.00  2011.0            CALIFORNIA
# 3002366         39832.00  2011.0                 TEXAS
# 3002367         50357.00  2011.0                OREGON
# 3002369         46738.00  2011.0               GEORGIA
# 3002378         45760.00  2011.0              ILLINOIS
# 3002383         54080.00  2011.0  DISTRICT OF COLUMBIA
# 3002389         55141.00  2011.0              MICHIGAN
# 3002392         69368.00  2011.0              NEW YORK
#
# [2597292 rows x 8 columns]
